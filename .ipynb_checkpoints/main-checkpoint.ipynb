# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
from tensorflow.python.keras.layers import Activation, Dropout, Flatten, Dense

# %%
# Каталог с данными для обучения
train_dir = './data2.0/train'
# Каталог с данными для проверки
val_dir = './data2.0/val'
# Каталог с данными для тестирования
test_dir = './data2.0/test'
# Размеры изображения
img_width, img_height = 16, 16
# Размерность тензора на основе изображения для входных данных в нейронную сеть
# backend Tensorflow, channels_last
input_shape = (img_width, img_height, 3)
# Количество эпох
epochs = 10

# %%
datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_generator = datagen.flow_from_directory(
    './data2.0/train',
    target_size=(16, 16),
    batch_size=20,
    class_mode='categorical')
# Out:
# Found 2923 images belonging to 10 classes.

# %%
val_generator = datagen.flow_from_directory(
    './data2.0/val',
    target_size=(img_width, img_height),
    batch_size=30,
    class_mode='categorical')
# Out:
# Found 714 images belonging to 10 classes.

# %%
test_generator = datagen.flow_from_directory(
    './data2.0/test/',
    target_size=(img_width, img_height),
    batch_size=13,
    class_mode='categorical')
# Out:
# Found 716 images belonging to 10 classes.

# %% [markdown]
# # Сверточная нейронная сеть

# %%
# Создаем последовательную модель
model = Sequential()

model.add(Conv2D(75, kernel_size=(5, 5),
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(100, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
model.fit_generator(
    train_generator,
    steps_per_epoch=143,
    epochs=4,
    validation_data=val_generator,
    validation_steps=35)
# Out:
# Epoch 1/4
# 143/143 [==============================]143/143 [==============================] - 434s 3s/step - loss: 0.0087 - acc: 0.9986 - val_loss: 0.0017 - val_acc: 1.0000
#
# Epoch 2/4
#  40/143 [=======>......................] 40/143 [=======>......................] - ETA: 4:53 - loss: 0.0024 - acc: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-7914f9393cb3> in <module>()
#       4     epochs=4,
#       5     validation_data=val_generator,
# ----> 6     validation_steps=35)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, **kwargs)
#    1196         use_multiprocessing=use_multiprocessing,
#    1197         shuffle=shuffle,
# -> 1198         initial_epoch=initial_epoch)
#    1199
#    1200   def evaluate_generator(self,
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2343
#    2344           outs = self.train_on_batch(
# -> 2345               x, y, sample_weight=sample_weight, class_weight=class_weight)
#    2346
#    2347           if not isinstance(outs, list):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1990     if context.in_graph_mode():
#    1991       self._make_train_function()
# -> 1992       outputs = self.train_function(ins)
#    1993       if len(outputs) == 1:
#    1994         return outputs[0]
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/backend.py in __call__(self, inputs)
#    2661     session = get_session()
#    2662     updated = session.run(
# -> 2663         fetches=fetches, feed_dict=feed_dict, **self.session_kwargs)
#    2664     return updated[:len(self.outputs)]
#    2665
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Сохранение модели

# %%
model_json = model.to_json()
# Записываем модель в файл
json_file = open("model.json", "w")
json_file.write(model_json)
json_file.close()

# %%
#Сохраняем веса модели
model.save_weights("model_weights.h5")

# %%
scores = model.evaluate_generator(test_generator, 1)

# %%
scores
# Out:
# [5.2323423005873337e-05, 1.0]

# %%
import numpy as np
from keras.preprocessing import image
from PIL import Image
from keras.utils import np_utils
from keras.models import model_from_json
import os
# Out:
# Using TensorFlow backend.

# %%
path = './data2.0/test2/'
predictions=[]
print()
for image_path in sorted(os.listdir(path)):
    img = image.load_img(path + image_path, target_size=(16, 16))
    x = image.img_to_array(img)
    # x = 255 - x
    x /= 255
    x = np.expand_dims(x, axis=0)

    prediction = model.predict(x)
#     print(prediction)

#     prediction = np_utils.categorical_probas_to_classes(prediction)
    prediction = np.argmax(prediction, axis=1)
    predictions.append(prediction)
    print(image_path,prediction)

print(predictions)
# Out:
# 1.png [0]
# 1_2.png [0]
# 2.png [0]
# 2_1.png [0]
# 2_2.png [0]
# 2_3.png [6]
# 2_4.png [0]
# 3_1.png [0]
# 3_2.png [4]
# 4_1.png [4]
# 4_2.png [4]
# 4_3.png [5]
# 4_4.png [4]
# 4_5.png [5]
# 4_6.png [4]
# 4_7.png [5]
# 5.png [4]
# 5_1.png [5]
# 5_2.png [5]
# 5_3.png [5]
# 5_4.png [5]
# 5_5.png [5]
# 5_7.png [5]
# 5_8.png [4]
# 5_9.png [4]
# 6_1.png [5]
# 6_2png [6]
# 6_3.png [6]
# 6_4.png [6]
# 6_5.png [6]
# 6_6.png [6]
# 6_7.png [5]
# [array([0]), array([0]), array([0]), array([0]), array([0]), array([6]), array([0]), array([0]), array([4]), array([4]), array([4]), array([5]), array([4]), array([5]), array([4]), array([5]), array([4]), array([5]), array([5]), array([5]), array([5]), array([5]), array([5]), array([4]), array([4]), array([5]), array([6]), array([6]), array([6]), array([6]), array([6]), array([5])]

# %%
test2_generator = datagen.flow_from_directory(
    './data2.0/test2/',
    target_size=(img_width, img_height),
    batch_size=13,
    class_mode='categorical')
# Out:
# Found 129 images belonging to 10 classes.

# %%
scores = model.evaluate_generator(test_generator, 36)

# %%
import numpy as np
from keras.preprocessing import image
from PIL import Image
from keras.utils import np_utils
from keras.models import model_from_json

# %%
img_path = './train/3/2.png'
img = image.load_img(img_path, target_size=(16, 16))
x = image.img_to_array(img)
# x = 255 - x
x /= 255
x = np.expand_dims(x, axis=0)

# json_file = open('mnist_cnn_model_desktop.json', 'r')
# json_file = open('mnist_siamese_graph.json', 'r')
# json_file = open('mnist_mlp_model.json', 'r')
# json_file = open('mnist_hierarchical_rnn_model_desktop.json', 'r')
# json_file = open('mnist_irnn_model_desktop.json', 'r')
json_file = open('model.json', 'r')
# json_file = open('mnist_cnn_model_vscale.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# loaded_model.load_weights("mnist_cnn_model_desktop.h5")
# loaded_model.load_weights("mnist_siamese_graph.h5")
# loaded_model.load_weights("mnist_hierarchical_rnn_model_desktop.h5")
# loaded_model.load_weights("mnist_irnn_model_desktop.h5")
loaded_model.load_weights("model_weights.h5")
# loaded_model.load_weights("mnist_cnn_model_vscale.h5")

loaded_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
prediction = loaded_model.predict(x)
# prediction = np_utils.categorical_probas_to_classes(prediction)
prediction = np.argmax(prediction, axis=1)
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-72ede998211e> in <module>()
#       1 img_path = './train/3/2.png'
# ----> 2 img = image.load_img(img_path, target_size=(16, 16))
#       3 x = image.img_to_array(img)
#       4 # x = 255 - x
#       5 x /= 255
#
# ~/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py in load_img(path, grayscale, target_size, interpolation)
#     360         raise ImportError('Could not import PIL.Image. '
#     361                           'The use of `array_to_img` requires PIL.')
# --> 362     img = pil_image.open(path)
#     363     if grayscale:
#     364         if img.mode != 'L':
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2475
#    2476     if filename:
# -> 2477         fp = builtins.open(filename, "rb")
#    2478         exclusive_fp = True
#    2479
#
# FileNotFoundError: [Errno 2] No such file or directory: './train/3/2.png'

# %%
predictions = model.predict_generator(test_generator,1)

# %%
predictions, len(predictions)
# Out:
# (array([[  9.99230504e-01,   1.48250842e-06,   7.68039667e-04,
#            4.79249583e-12,   3.94523134e-08,   5.10458378e-08,
#            6.00527517e-10,   1.59675759e-10,   1.76316583e-11,
#            5.94315916e-11],
#         [  1.45472365e-03,   4.59051644e-03,   3.99939709e-05,
#            5.60594231e-07,   5.30119846e-03,   9.24233019e-01,
#            6.39048293e-02,   3.59154015e-04,   1.29163811e-06,
#            1.14534661e-04],
#         [  2.36715190e-03,   1.95861134e-07,   9.97628152e-01,
#            1.22390338e-06,   3.17236959e-06,   4.98950037e-08,
#            3.33833494e-09,   1.75595394e-09,   4.11607104e-09,
#            6.33304467e-08],
#         [  3.82689410e-04,   7.78919101e-01,   2.32725852e-05,
#            2.78242965e-07,   1.02199670e-02,   2.05314592e-01,
#            5.06275240e-03,   4.85589371e-05,   5.35441188e-07,
#            2.82538713e-05],
#         [  9.99787152e-01,   1.75491920e-07,   2.12700645e-04,
#            4.41102233e-12,   1.29609026e-08,   4.28699494e-08,
#            2.44215037e-10,   1.52730224e-11,   3.91396160e-12,
#            4.00004335e-12],
#         [  6.77184144e-05,   4.93141840e-07,   7.75498688e-01,
#            5.11310026e-02,   9.13849090e-06,   3.93380020e-07,
#            7.82429561e-05,   8.92518554e-03,   1.64235398e-01,
#            5.38374297e-05],
#         [  9.00902087e-05,   6.51220205e-07,   1.86549544e-01,
#            8.13299119e-01,   2.07896683e-05,   1.54970348e-06,
#            2.23501252e-06,   1.56181386e-07,   2.84983944e-05,
#            7.38297013e-06],
#         [  8.34873063e-05,   1.15944744e-07,   9.99258101e-01,
#            6.14222779e-04,   1.55227360e-06,   1.09993407e-05,
#            2.41556754e-05,   8.99166164e-09,   4.46982949e-06,
#            2.89098534e-06],
#         [  9.99608457e-01,   2.64116011e-06,   3.88690736e-04,
#            3.20069860e-12,   4.64203787e-08,   2.17252278e-07,
#            1.43893264e-09,   7.55571369e-11,   6.12547990e-12,
#            9.06777292e-11],
#         [  5.07173967e-03,   4.93477136e-01,   4.41162811e-05,
#            1.14668705e-06,   1.00643905e-02,   4.73492205e-01,
#            1.77024864e-02,   1.20918907e-04,   2.67723590e-06,
#            2.31871982e-05],
#         [  9.99991298e-01,   1.01681451e-06,   2.61912874e-06,
#            4.86370800e-06,   1.51402432e-07,   4.94748287e-09,
#            7.03063741e-09,   4.12476631e-09,   1.40560463e-09,
#            4.85063323e-09],
#         [  9.99984145e-01,   1.58925303e-07,   1.57520808e-05,
#            3.12761622e-12,   6.20083984e-09,   4.10611243e-08,
#            3.74544867e-10,   1.20434461e-11,   1.63692551e-12,
#            1.44511356e-12],
#         [  7.23282993e-01,   3.59979074e-10,   1.90000772e-01,
#            6.79062083e-02,   1.88083723e-02,   1.72498693e-09,
#            5.75113235e-10,   2.57875610e-10,   1.93067806e-09,
#            1.53532790e-06]], dtype=float32), 13)

# %%
model.get_weights()
# Out:
# [array([[[[-0.0017946 , -0.05830353, -0.0344357 , ..., -0.00657272,
#            -0.06967971, -0.04115363],
#           [ 0.04073418, -0.0756893 , -0.01976301, ...,  0.02410554,
#            -0.097503  ,  0.03637939],
#           [ 0.00779665, -0.00501972,  0.02450109, ..., -0.01718332,
#            -0.01630603, -0.03514912]],
#
#          [[-0.03078166, -0.01981171, -0.00431708, ...,  0.06027627,
#             0.0218971 ,  0.06821515],
#           [ 0.00519137,  0.05050354, -0.03395135, ...,  0.01334142,
#             0.06588516,  0.00068092],
#           [-0.07808213, -0.02471543,  0.04966554, ...,  0.04908391,
#             0.03816191,  0.01390228]],
#
#          [[ 0.00588462, -0.00389914, -0.10927515, ...,  0.05757616,
#             0.03773757, -0.01785219],
#           [-0.05140675,  0.04243286, -0.1192234 , ..., -0.01465235,
#             0.02922991,  0.02247916],
#           [ 0.020911  , -0.00997932, -0.06145214, ...,  0.05314989,
#            -0.01895558, -0.06598119]],
#
#          [[-0.02058547, -0.00233026,  0.05422262, ..., -0.05502079,
#            -0.08199246, -0.10398203],
#           [-0.06826841, -0.03688848,  0.03936046, ..., -0.00091203,
#            -0.04475086, -0.06370702],
#           [ 0.0143021 , -0.0106038 ,  0.0562371 , ..., -0.07511126,
#            -0.07842503, -0.08663915]],
#
#          [[-0.03669495, -0.0403412 ,  0.01671661, ..., -0.01829367,
#             0.04614174,  0.00077857],
#           [ 0.06451977,  0.0138995 ,  0.06245946, ..., -0.04692816,
#             0.01956741,  0.01493476],
#           [-0.0336724 , -0.05166909, -0.03311682, ..., -0.05687323,
#            -0.0509497 ,  0.04684273]]],
#
#
#         [[[ 0.00624585, -0.05957545,  0.04922479, ..., -0.01323574,
#            -0.10475168,  0.03807646],
#           [-0.02342425,  0.01013885, -0.00205676, ..., -0.0300504 ,
#            -0.08697997, -0.00718687],
#           [ 0.00756541, -0.04010933, -0.02455286, ..., -0.01991058,
#            -0.04079532, -0.01487255]],
#
#          [[ 0.00312665, -0.02624381,  0.03819418, ...,  0.07143289,
#            -0.0077536 ,  0.014396  ],
#           [-0.07059772, -0.04647003,  0.07978311, ...,  0.05427008,
#             0.06940731,  0.04491955],
#           [-0.04738752,  0.04399532,  0.03404597, ..., -0.01825467,
#             0.00324564,  0.08205948]],
#
#          [[ 0.00947847, -0.02494753, -0.14733309, ..., -0.06581846,
#             0.02955825, -0.07291432],
#           [ 0.01055394, -0.00179646, -0.13758934, ..., -0.03568598,
#             0.06420131, -0.0317891 ],
#           [-0.04075327, -0.01142448, -0.1475794 , ..., -0.06178495,
#            -0.01174696, -0.08405564]],
#
#          [[-0.04116609,  0.04028105, -0.01555041, ..., -0.07009261,
#            -0.02612852, -0.03084171],
#           [-0.00786844,  0.04666755, -0.01903918, ..., -0.05855181,
#            -0.02701771, -0.05322166],
#           [-0.05774919,  0.00214718,  0.02979072, ..., -0.03020506,
#            -0.03231427, -0.04389755]],
#
#          [[ 0.04579259, -0.05468868,  0.01605178, ..., -0.02635166,
#            -0.01123321,  0.03771097],
#           [ 0.01497699,  0.03268394,  0.06019963, ..., -0.04017223,
#            -0.06357664,  0.01849076],
#           [-0.02191185, -0.04358298, -0.04326471, ..., -0.01056605,
#             0.03121126, -0.00797129]]],
#
#
#         [[[ 0.0449553 , -0.05156728, -0.01112475, ..., -0.07318685,
#            -0.03385278,  0.00096874],
#           [ 0.02628645,  0.03296113,  0.02364691, ..., -0.08993959,
#            -0.0723227 , -0.03722955],
#           [ 0.04029607, -0.05676021,  0.01211274, ..., -0.08616995,
#            -0.03867517, -0.05367505]],
#
#          [[ 0.02272409,  0.00183942,  0.09188619, ..., -0.01813995,
#             0.07923626,  0.05437831],
#           [ 0.00640744, -0.03038047,  0.02182022, ..., -0.08336437,
#             0.07257909,  0.00998421],
#           [-0.00063909,  0.01893043,  0.01769994, ..., -0.06386559,
#            -0.01299866,  0.04720289]],
#
#          [[-0.02032381, -0.04658086, -0.0441169 , ...,  0.01235125,
#            -0.03564519, -0.07289881],
#           [-0.03039086,  0.00435874, -0.0253555 , ..., -0.01448984,
#             0.02155377,  0.02027624],
#           [ 0.03386995,  0.02359563, -0.11145119, ..., -0.04892446,
#             0.03774603, -0.0760259 ]],
#
#          [[-0.00574194, -0.03241807, -0.02771243, ...,  0.0712984 ,
#             0.02550759, -0.01786168],
#           [-0.0335577 , -0.06212028,  0.05518663, ...,  0.06750531,
#             0.01929578, -0.00884136],
#           [ 0.01844404,  0.01958591, -0.01830253, ...,  0.02454068,
#             0.03644299, -0.03857126]],
#
#          [[-0.02520591,  0.0483478 ,  0.04082999, ...,  0.05136145,
#             0.03442013,  0.00904575],
#           [ 0.05986933,  0.039404  , -0.00595986, ...,  0.01083006,
#            -0.07490946, -0.01345011],
#           [ 0.03748508,  0.0157428 , -0.00701383, ...,  0.05880712,
#            -0.01961974, -0.02176309]]],
#
#
#         [[[-0.00883453, -0.00104979, -0.04916741, ..., -0.01283886,
#            -0.06536186,  0.02753257],
#           [ 0.0587084 , -0.03850035, -0.0341564 , ...,  0.00727116,
#            -0.10562462,  0.0298394 ],
#           [ 0.03882984,  0.02824754,  0.01668686, ...,  0.03252914,
#            -0.04216035, -0.00343367]],
#
#          [[-0.02607315, -0.01482277,  0.02407924, ..., -0.06776049,
#             0.06293427,  0.0719822 ],
#           [ 0.03061909,  0.01814811,  0.02576938, ..., -0.00445634,
#             0.06421806,  0.0801072 ],
#           [-0.00940606,  0.01725457,  0.04832235, ..., -0.07051697,
#             0.06413499,  0.01754793]],
#
#          [[ 0.01914048, -0.04424887, -0.092748  , ...,  0.00879868,
#             0.05442521, -0.08777595],
#           [ 0.01816238,  0.01932166, -0.02736922, ..., -0.01538663,
#             0.03735419, -0.07725111],
#           [-0.03829545, -0.02239717, -0.11264504, ..., -0.000419  ,
#             0.00092883, -0.09699889]],
#
#          [[ 0.04439232,  0.01080725,  0.01445908, ..., -0.00490424,
#             0.0305315 , -0.02388589],
#           [-0.01905015,  0.01475273,  0.09275422, ...,  0.05340171,
#            -0.0244978 ,  0.01785069],
#           [-0.01385002, -0.04281966,  0.08547632, ...,  0.02463243,
#            -0.03795811,  0.00017084]],
#
#          [[-0.01455415, -0.01770111,  0.01586449, ...,  0.01578506,
#            -0.02466912,  0.0401137 ],
#           [ 0.03133804, -0.03610678,  0.0210388 , ...,  0.05472703,
#            -0.02987162, -0.04646855],
#           [ 0.03618154,  0.04238816,  0.03988533, ...,  0.04379999,
#             0.02420823, -0.04537142]]],
#
#
#         [[[ 0.06540557,  0.01047867, -0.01398147, ...,  0.08861032,
#            -0.06157119,  0.01796393],
#           [ 0.04970159, -0.04772955, -0.04268437, ...,  0.01835633,
#            -0.10115197,  0.0132076 ],
#           [ 0.0112887 , -0.05522042,  0.01331213, ...,  0.06529456,
#            -0.06306312, -0.00271423]],
#
#          [[-0.03176584, -0.04961339,  0.03530718, ..., -0.03672596,
#             0.05497675,  0.0697092 ],
#           [-0.04090412,  0.02590989,  0.02940855, ..., -0.00987371,
#             0.05923179,  0.04627863],
#           [ 0.03286463, -0.0279626 ,  0.04847855, ..., -0.03593876,
#            -0.00147478,  0.02833978]],
#
#          [[-0.00783239, -0.05745277, -0.09460014, ...,  0.00196132,
#             0.06848489,  0.00610357],
#           [ 0.0206018 , -0.00194316, -0.06900878, ...,  0.057485  ,
#             0.0033389 , -0.06579711],
#           [-0.0219596 , -0.00646925, -0.13066027, ...,  0.03279825,
#            -0.01309476,  0.02157802]],
#
#          [[ 0.00149552,  0.00590569,  0.07391381, ...,  0.03482832,
#            -0.06017865, -0.01668917],
#           [ 0.01505718,  0.02480444, -0.01547954, ..., -0.01482926,
#             0.04062903,  0.0188471 ],
#           [-0.02419822, -0.04369074,  0.04853491, ...,  0.07846215,
#             0.03185658,  0.01449271]],
#
#          [[ 0.01177244,  0.03672066,  0.06675974, ...,  0.01106004,
#             0.02562668,  0.03710293],
#           [ 0.03141499, -0.03589954,  0.06232669, ...,  0.0444022 ,
#            -0.01869623,  0.005625  ],
#           [ 0.00716952,  0.01399115, -0.01851211, ...,  0.00421593,
#            -0.06773786,  0.06465313]]]], dtype=float32),
#  array([-0.01434332,  0.0028535 , -0.01102124,  0.02338207,  0.00941655,
#         -0.01284785,  0.01990023,  0.01618324,  0.04460401,  0.03734209,
#          0.00939199,  0.04854301, -0.0231083 , -0.01145916, -0.03462253,
#          0.04555567,  0.03001824,  0.00706345,  0.02592284,  0.02175102,
#          0.03396738,  0.018319  ,  0.03113072, -0.01303576,  0.01845246,
#          0.01255591,  0.0163506 ,  0.00485862,  0.01470385, -0.02129208,
#          0.01477437,  0.03748504, -0.00484729,  0.01646591, -0.01434921,
#         [ 0.02038118, -0.10354259,  0.04358096, ..., -0.09915597,
#          -0.10585493, -0.0903797 ],
#         [-0.05288978, -0.03197806, -0.00770426, ..., -0.10596594,
#           0.01831962,  0.08597119],
#         ...,
#         [-0.05746038,  0.06398644,  0.05820584, ..., -0.01396421,
#           0.02219165, -0.07506604],
#         [ 0.01193123,  0.12386973, -0.01080806, ...,  0.0004954 ,
#          -0.12535538, -0.10241367],
#         [ 0.03257424, -0.08961595,  0.06644337, ..., -0.0453858 ,
#          -0.09367139, -0.09679551]], dtype=float32),
#  array([ 0.0262916 , -0.02196835,  0.01075778, -0.00683012,  0.00981394,
#         -0.00628877,  0.01218078, -0.00057264, -0.01730457, -0.02406112], dtype=float32)]

# %% [markdown]
# # Последовательная модель

# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
from tensorflow.python.keras.layers import Activation, Dropout, Flatten, Dense

# %%
input_shape = (16,16,3)
img_width, img_height = 16,16

# %%
# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(800, input_shape=input_shape, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16, 16, 800)       3200
# _________________________________________________________________
# dense_4 (Dense)              (None, 16, 16, 10)        8010
# =================================================================
# Total params: 11,210
# Trainable params: 11,210
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_generator = datagen.flow_from_directory(
    './data2.0/train',
    target_size=(16, 16),
    batch_size=20,
    class_mode='categorical')
# Out:
# Found 2923 images belonging to 10 classes.

# %%
val_generator = datagen.flow_from_directory(
    './data2.0/val',
    target_size=(img_width, img_height),
    batch_size=20,
    class_mode='categorical')
# Out:
# Found 714 images belonging to 10 classes.

# %%
test_generator = datagen.flow_from_directory(
    './data2.0/test/',
    target_size=(img_width, img_height),
    batch_size=20,
    class_mode='categorical')
# Out:
# Found 716 images belonging to 10 classes.

# %%
# Обучаем сеть
model.fit_generator(
    train_generator,
    steps_per_epoch=58,
    epochs=10,
    validation_data=val_generator,
    validation_steps=20)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-9f54c04fac3d> in <module>()
#       5     epochs=10,
#       6     validation_data=val_generator,
# ----> 7     validation_steps=20)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, **kwargs)
#    1196         use_multiprocessing=use_multiprocessing,
#    1197         shuffle=shuffle,
# -> 1198         initial_epoch=initial_epoch)
#    1199
#    1200   def evaluate_generator(self,
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2343
#    2344           outs = self.train_on_batch(
# -> 2345               x, y, sample_weight=sample_weight, class_weight=class_weight)
#    2346
#    2347           if not isinstance(outs, list):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1979         sample_weight=sample_weight,
#    1980         class_weight=class_weight,
# -> 1981         check_batch_axis=True)
#    1982     if self.uses_learning_phase and not isinstance(K.learning_phase(), int):
#    1983       ins = x + y + sample_weights + [1.]
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1512         output_shapes,
#    1513         check_batch_axis=False,
# -> 1514         exception_prefix='target')
#    1515     sample_weights = _standardize_sample_weights(sample_weight,
#    1516                                                  self._feed_output_names)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     137                            ': expected ' + names[i] + ' to have ' +
#     138                            str(len(shape)) + ' dimensions, but got array '
# --> 139                            'with shape ' + str(data_shape))
#     140         if not check_batch_axis:
#     141           data_shape = data_shape[1:]
#
# ValueError: Error when checking target: expected dense_4 to have 4 dimensions, but got array with shape (20, 10)
